# %% [markdown]
# # Google Images Crawler

# %% [markdown]
# Quick jupyter notebook for Google Images scraping. Google images now features an infinite scroll, therefore we're gonna use Selenium for this scraping.

# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import sys
import os
import traceback
import re
import time
import json
import unidecode

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# We're gonna try with one headers first. If this doesn't work, we're gonna try proxy rotation and multi-headers to hide our identity. But given the fact that we are not going to scrap a lot of data, we might be able to go anonymous. Google Images should not raise an issue though.

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:62.0) Gecko/20100101 Firefox/62.0'}

# %% [markdown]
# Choose the kind of images you want to get. Here, we're gonna try pants (Cargo, Chinos, Casual and Dungarees), and the path to save your data. We show and example for our first search, 'Pantalons Cargos'.

# %%
DownloadPath = "/media/arthur/DATA/Databases/GoogleImagesScraping/Pantalons"

# Parameters
words_to_search = ['Pantalons Cargos', 'Pantalons Chinos', 'Pantalons Casuals', 'Salopette']
nb_to_download = [1000, 1000, 1000, 1000]
first_image_position = [0, 0, 0, 0]

# Number of scrolls (because of infinite scroll)
number_of_scrolls = int((nb_to_download[0] + first_image_position[0])/ 400 + 1)

# %% [markdown]
# Create the folders to save the images

# %%
if not os.path.exists(DownloadPath + words_to_search[0].replace(" ", "_")):
    os.makedirs(DownloadPath + words_to_search[0].replace(" ", "_"))

# %% [markdown]
# We are now ready to start. Selenium is gonna create an instance of our web browser (in my case, Mozilla Firefox) which will be controlled by this script.
# Tip for installing: go to https://github.com/mozilla/geckodriver/releases and get the geckodriver corresponding to your brwoser.

# %%
url = "https://www.google.co.in/search?q=" + words_to_search[0] + "&source=lnms&tbm=isch"
driver = webdriver.Firefox()
driver.get(url)
extensions = {"jpg", "jpeg", "png"}

# %% [markdown]
# Now, we automatically scroll the page to load all the images we want to download. We use the scrollBy script in Selenium.
# Tips: Need to put a sleep between each scroll to allow the images to be loaded on the page. If not, your crawler will stop cause it has no time to scroll down.

# %%
for _ in range(5):
    driver.execute_script("window.scrollBy(0,1000000)")
    time.sleep(1)

# %% [markdown]
# Now that our crawler is at the bottom of the page, we can download the images. Our crawler gets 303 images, whereas we only had 103 without the scroll down.

# %%
images = driver.find_elements_by_xpath('//div[contains(@class, "rg_meta")]')
print(len(images))
i = 0
for img in images:
    i+=1
    print("Dowloading image no", i)
    img_url = json.loads(img.get_attribute('innerHTML'))["ou"]
    img_type = json.loads(img.get_attribute('innerHTML'))["ity"]
    file_name =DownloadPath + words_to_search[0].replace(" ", "_")+"/"+ str(i)+"."+img_type
    f = open(file_name, 'wb')
    try:
        urllib.request.urlretrieve(img_url, file_name)
    except Exception:
        print("Downloading Unauthorized")
        continue
# Out:
# 303
# Dowloading image no 1
# Dowloading image no 2
# Dowloading image no 3
# Dowloading image no 4
# Dowloading image no 5
# Dowloading image no 6
# Dowloading image no 7
# Dowloading image no 8
# Dowloading image no 9
# Dowloading image no 10
# Dowloading image no 11
# Dowloading image no 12
# Dowloading image no 13
# Dowloading image no 14
# Dowloading image no 15
# Dowloading image no 16
# Dowloading image no 17
# Dowloading image no 18
# Dowloading image no 19
# Dowloading image no 20
# Dowloading image no 21
# Dowloading image no 22
# Dowloading image no 23
# Dowloading image no 24
# Dowloading image no 25
# Dowloading image no 26
# Dowloading image no 27
# Dowloading image no 28
# Dowloading image no 29
# Dowloading image no 30
# Downloading Unauthorized
# Dowloading image no 31
# Dowloading image no 32
# Dowloading image no 33
# Dowloading image no 34
# Dowloading image no 35
# Dowloading image no 36
# Dowloading image no 37
# Dowloading image no 38
# Dowloading image no 39
# Dowloading image no 40
# Dowloading image no 41
# Dowloading image no 42
# Dowloading image no 43
# Dowloading image no 44
# Dowloading image no 45
# Dowloading image no 46
# Dowloading image no 47
# Dowloading image no 48
# Dowloading image no 49
# Dowloading image no 50
# Dowloading image no 51
# Dowloading image no 52
# Dowloading image no 53
# Dowloading image no 54
# Dowloading image no 55
# Dowloading image no 56
# Dowloading image no 57
# Downloading Unauthorized
# Dowloading image no 58
# Dowloading image no 59
# Dowloading image no 60
# Dowloading image no 61
# Dowloading image no 62
# Dowloading image no 63
# Dowloading image no 64
# Dowloading image no 65
# Dowloading image no 66
# Dowloading image no 67
# Downloading Unauthorized
# Dowloading image no 68
# Dowloading image no 69
# Downloading Unauthorized
# Dowloading image no 70
# Dowloading image no 71
# Dowloading image no 72
# Dowloading image no 73
# Dowloading image no 74
# Dowloading image no 75
# Dowloading image no 76
# Dowloading image no 77
# Dowloading image no 78
# Dowloading image no 79
# Dowloading image no 80
# Dowloading image no 81
# Dowloading image no 82
# Dowloading image no 83
# Dowloading image no 84
# Dowloading image no 85
# Dowloading image no 86
# Dowloading image no 87
# Dowloading image no 88
# Dowloading image no 89
# Dowloading image no 90
# Dowloading image no 91
# Dowloading image no 92
# Downloading Unauthorized
# Dowloading image no 93
# Dowloading image no 94
# Dowloading image no 95
# Dowloading image no 96
# Dowloading image no 97
# Dowloading image no 98
# Dowloading image no 99
# Dowloading image no 100
# Dowloading image no 101
# Dowloading image no 102
# Dowloading image no 103
# Dowloading image no 104
# Dowloading image no 105
# Dowloading image no 106
# Dowloading image no 107
# Dowloading image no 108
# Dowloading image no 109
# Dowloading image no 110
# Dowloading image no 111
# Dowloading image no 112
# Dowloading image no 113
# Dowloading image no 114
# Dowloading image no 115
# Dowloading image no 116
# Dowloading image no 117
# Dowloading image no 118
# Dowloading image no 119
# Dowloading image no 120
# Dowloading image no 121
# Dowloading image no 122
# Dowloading image no 123
# Dowloading image no 124
# Dowloading image no 125
# Dowloading image no 126
# Dowloading image no 127
# Dowloading image no 128
# Dowloading image no 129
# Dowloading image no 130
# Dowloading image no 131
# Dowloading image no 132
# Dowloading image no 133
# Dowloading image no 134
# Dowloading image no 135
# Dowloading image no 136
# Dowloading image no 137
# Dowloading image no 138
# Dowloading image no 139
# Downloading Unauthorized
# Dowloading image no 140
# Dowloading image no 141
# Dowloading image no 142
# Dowloading image no 143
# Dowloading image no 144
# Dowloading image no 145
# Dowloading image no 146
# Dowloading image no 147
# Dowloading image no 148
# Dowloading image no 149
# Dowloading image no 150
# Dowloading image no 151
# Dowloading image no 152
# Downloading Unauthorized
# Dowloading image no 153
# Dowloading image no 154
# Dowloading image no 155
# Dowloading image no 156
# Downloading Unauthorized
# Dowloading image no 157
# Dowloading image no 158
# Dowloading image no 159
# Dowloading image no 160
# Dowloading image no 161
# Dowloading image no 162
# Dowloading image no 163
# Downloading Unauthorized
# Dowloading image no 164
# Dowloading image no 165
# Dowloading image no 166
# Dowloading image no 167
# Dowloading image no 168
# Dowloading image no 169
# Dowloading image no 170
# Dowloading image no 171
# Dowloading image no 172
# Dowloading image no 173
# Dowloading image no 174
# Dowloading image no 175
# Downloading Unauthorized
# Dowloading image no 176
# Dowloading image no 177
# Dowloading image no 178
# Downloading Unauthorized
# Dowloading image no 179
# Dowloading image no 180
# Dowloading image no 181
# Dowloading image no 182
# Dowloading image no 183
# Dowloading image no 184
# Dowloading image no 185
# Dowloading image no 186
# Downloading Unauthorized
# Dowloading image no 187
# Dowloading image no 188
# Dowloading image no 189
# Dowloading image no 190
# Dowloading image no 191
# Dowloading image no 192
# Dowloading image no 193
# Dowloading image no 194
# Dowloading image no 195
# Dowloading image no 196
# Dowloading image no 197
# Dowloading image no 198
# Downloading Unauthorized
# Dowloading image no 199
# Dowloading image no 200
# Downloading Unauthorized
# Dowloading image no 201
# Dowloading image no 202
# Dowloading image no 203
# Dowloading image no 204
# Dowloading image no 205
# Downloading Unauthorized
# Dowloading image no 206
# Dowloading image no 207
# Dowloading image no 208
# Dowloading image no 209
# Dowloading image no 210
# Dowloading image no 211
# Dowloading image no 212
# Dowloading image no 213
# Dowloading image no 214
# Dowloading image no 215
# Dowloading image no 216
# Dowloading image no 217
# Dowloading image no 218
# Dowloading image no 219
# Dowloading image no 220
# Dowloading image no 221
# Dowloading image no 222
# Dowloading image no 223
# Dowloading image no 224
# Dowloading image no 225
# Downloading Unauthorized
# Dowloading image no 226
# Dowloading image no 227
# Dowloading image no 228
# Dowloading image no 229
# Downloading Unauthorized
# Dowloading image no 230
# Dowloading image no 231
# Downloading Unauthorized
# Dowloading image no 232
# Dowloading image no 233
# Dowloading image no 234
# Dowloading image no 235
# Dowloading image no 236
# Dowloading image no 237
# Dowloading image no 238
# Dowloading image no 239
# Dowloading image no 240
# Dowloading image no 241
# Dowloading image no 242
# Dowloading image no 243
# Dowloading image no 244
# Dowloading image no 245
# Dowloading image no 246
# Dowloading image no 247
# Dowloading image no 248
# Dowloading image no 249
# Dowloading image no 250
# Dowloading image no 251
# Dowloading image no 252
# Downloading Unauthorized
# Dowloading image no 253
# Dowloading image no 254
# Dowloading image no 255
# Dowloading image no 256
# Dowloading image no 257
# Dowloading image no 258
# Dowloading image no 259
# Dowloading image no 260
# Dowloading image no 261
# Dowloading image no 262
# Dowloading image no 263
# Dowloading image no 264
# Dowloading image no 265
# Downloading Unauthorized
# Dowloading image no 266
# Dowloading image no 267
# Dowloading image no 268
# Dowloading image no 269
# Dowloading image no 270
# Dowloading image no 271
# Dowloading image no 272
# Dowloading image no 273
# Dowloading image no 274
# Dowloading image no 275
# Dowloading image no 276
# Dowloading image no 277
# Dowloading image no 278
# Dowloading image no 279
# Dowloading image no 280
# Dowloading image no 281
# Dowloading image no 282
# Dowloading image no 283
# Dowloading image no 284
# Dowloading image no 285
# Dowloading image no 286
# Dowloading image no 287
# Dowloading image no 288
# Dowloading image no 289
# Dowloading image no 290
# Dowloading image no 291
# Downloading Unauthorized
# Dowloading image no 292
# Dowloading image no 293
# Dowloading image no 294
# Dowloading image no 295
# Dowloading image no 296
# Dowloading image no 297
# Dowloading image no 298
# Dowloading image no 299
# Dowloading image no 300
# Downloading Unauthorized
# Dowloading image no 301
# Dowloading image no 302
# Downloading Unauthorized
# Dowloading image no 303
